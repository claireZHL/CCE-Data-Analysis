# %% [markdown]
# # San Diego Zipcode Clustering by Decmographic Features

# %% [markdown]
# ### Setup

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load & Clean Zipcode Data

# %%
# Load csv file of San Diego Zipcode
original_df = pd.read_csv('San Diego 2021 Zipcode.csv')
df = pd.read_csv('San Diego 2021 Zipcode.csv')
print(f'Number of Rows before Drop NaN: {len(df)}')

# drop any row with nan
original_df = original_df.dropna()
df = df.dropna()
print(f'Number of Rows before Drop NaN: {len(df)}')

# Set zipcode column to be the index
original_df.set_index('Zipcode', inplace=True)
df.set_index('Zipcode', inplace=True)

# Show the first few row of the dataframe
df.head()
# Out:
# Number of Rows before Drop NaN: 113
# Number of Rows before Drop NaN: 96
#          Population  Land Area (Sq. Miles)  \
# Zipcode
# 91902       17759.0                  11.22
# 91910       76291.0                  12.59
# 91911       88589.0                  12.73
# 91913       53725.0                   9.10
# 91914       17742.0                   6.64
#
#          Population Density (People per Square Mile)  Median Age  \
# Zipcode
# 91902                                        1583.23        45.8
# 91910                                        6061.25        38.2
# 91911                                        6960.37        35.8
# 91913                                        5906.59        35.0
# 91914                                        2670.34        37.1
#
#          Population By Age % (Under 18 Years)  Population By Age % (18 to 34)  \
# Zipcode
# 91902                                   17.62                           20.69
# 91910                                   21.70                           23.58
# 91911                                   24.01                           24.85
# 91913                                   25.91                           24.07
# 91914                                   25.17                           20.57
#
#          Population By Age % (35 to 64)  Population By Age % (65 and Over)  \
# Zipcode
# 91902                             38.98                              22.72
# 91910                             39.95                              14.77
# 91911                             38.28                              12.86
# 91913                             39.45                              10.58
# 91914                             44.35                               9.92
#
#          Male %  White %  ...  Carpooled %  Public Transit %  Motorcycle %  \
# Zipcode                   ...
# 91902     48.33    37.37  ...         5.10              0.97          0.16
# 91910     49.92    20.32  ...         9.54              3.86          0.52
# 91911     48.26    12.75  ...        11.53              4.16          0.18
# 91913     50.70    13.64  ...         9.89              0.87          0.26
# 91914     52.68    18.14  ...         6.05              1.19          0.08
#
#          Bicycle %  Walked %  Other %.1  Worked at Home %  \
# Zipcode
# 91902         0.37      0.00       1.53             10.71
# 91910         0.29      0.95       0.57              8.75
# 91911         0.19      1.23       1.04              5.67
# 91913         0.00      1.29       2.28             11.35
# 91914         0.43      7.09       3.51             10.57
#
#          Health Insurance Coverage %  Married %  Median House Value $
# Zipcode
# 91902                          94.78      52.66              732000.0
# 91910                          91.27      48.09              549100.0
# 91911                          90.78      49.91              485300.0
# 91913                          93.92      53.91              578600.0
# 91914                          93.01      61.59              739300.0
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Normalize Data

# %%
from sklearn.preprocessing import StandardScaler

# Select the columns you want to normalize
columns_to_normalize = df.columns

# Instantiate the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the selected columns
scaler.fit(df[columns_to_normalize])

# Transform the selected columns with Z-score scaling
df[columns_to_normalize] = scaler.transform(df[columns_to_normalize])

# Display the normalized DataFrame
df
# Out:
#          Population  Land Area (Sq. Miles)  \
# Zipcode
# 91902     -0.810811              -0.291858
# 91910      1.847808              -0.279514
# 91911      2.406404              -0.278253
# 91913      0.822824              -0.310958
# 91914     -0.811584              -0.333122
# ...             ...                    ...
# 92081     -0.257349              -0.312400
# 92083      0.148312              -0.342942
# 92084      0.642681              -0.137613
# 92091     -1.556998              -0.381323
# 92672      0.148176              -0.072563
#
#          Population Density (People per Square Mile)  Median Age  \
# Zipcode
# 91902                                      -0.677925    0.957445
# 91910                                       0.657912   -0.178781
# 91911                                       0.926128   -0.537589
# 91913                                       0.611775   -0.657192
# 91914                                      -0.353629   -0.343235
# ...                                              ...         ...
# 92081                                      -0.150555   -0.328285
# 92083                                       0.940378   -0.941249
# 92084                                      -0.626478   -0.642242
# 92091                                      -0.842493    2.811287
# 92672                                      -0.824153    0.135176
#
#          Population By Age % (Under 18 Years)  Population By Age % (18 to 34)  \
# Zipcode
# 91902                               -0.648347                       -0.378475
# 91910                                0.069802                       -0.014698
# 91911                                0.476401                        0.145162
# 91913                                0.810833                        0.046980
# 91914                                0.680580                       -0.393580
# ...                                       ...                             ...
# 92081                                0.245819                       -0.049943
# 92083                                0.828434                        0.501386
# 92084                                0.460559                        0.286141
# 92091                               -1.157036                       -1.630923
# 92672                               -0.636026                        0.437190
#
#          Population By Age % (35 to 64)  Population By Age % (65 and Over)  \
# Zipcode
# 91902                          0.052311                          -0.052901
# 91910                          0.296724                          -0.113913
# 91911                         -0.124070                          -0.128571
# 91913                          0.170738                          -0.146069
# 91914                          1.405403                          -0.151134
# ...                                 ...                                ...
# 92081                          0.541137                          -0.126883
# 92083                         -0.628015                          -0.150290
# 92084                         -0.391161                          -0.128341
# 92091                          0.188376                           0.041418
# 92672                         -0.469273                          -0.087282
#
#            Male %   White %  ...  Carpooled %  Public Transit %  Motorcycle %  \
# Zipcode                      ...
# 91902   -0.644861 -0.600839  ...    -0.707695         -0.521183     -0.407319
# 91910   -0.124802 -1.425166  ...     0.681427          0.860405      0.085917
# 91911   -0.667757 -1.791157  ...     1.304029          1.003822     -0.379917
# 91913    0.130321 -1.748127  ...     0.790930         -0.568989     -0.270309
# 91914    0.777942 -1.530563  ...    -0.410473         -0.416010     -0.516927
# ...           ...       ...  ...          ...               ...           ...
# 92081    0.270966  0.224454  ...    -0.645122         -0.640697      0.675060
# 92083   -0.082281 -1.120092  ...    -0.216496         -0.043125      0.264030
# 92084    0.513006 -0.391978  ...     0.221515         -0.736309     -0.585432
# 92091   -2.273725  0.712764  ...    -0.604449          0.358444     -0.626535
# 92672    0.414882  0.962721  ...    -0.128894         -0.468596     -0.558030
#
#          Bicycle %  Walked %  Other %.1  Worked at Home %  \
# Zipcode
# 91902    -0.145270 -0.874593   0.524611         -0.480817
# 91910    -0.255952 -0.493590  -0.525066         -0.811411
# 91911    -0.394305 -0.381295  -0.011162         -1.330917
# 91913    -0.657175 -0.357231   1.344671         -0.372868
# 91914    -0.062259  1.968888   2.689569         -0.504431
# ...            ...       ...        ...               ...
# 92081    -0.504987 -0.385305  -0.667210         -0.129982
# 92083    -0.408140 -0.373274   1.475880         -1.307303
# 92084    -0.269787 -0.561770  -0.229845         -0.666354
# 92091    -0.657175 -0.874593  -1.148312          1.502750
# 92672    -0.491152  2.321816   0.469940          0.173625
#
#          Health Insurance Coverage %  Married %  Median House Value $
# Zipcode
# 91902                       0.467977   0.117090              0.180409
# 91910                      -0.332152  -0.400228             -0.432641
# 91911                      -0.443851  -0.194206             -0.646487
# 91913                       0.271934   0.258588             -0.333762
# 91914                       0.064493   1.127953              0.204877
# ...                              ...        ...                   ...
# 92081                      -0.188539  -0.293821             -0.264044
# 92083                      -1.474217  -0.505502             -0.705815
# 92084                      -1.173313  -0.425131             -0.260022
# 92091                       0.082729  -0.198734              2.283346
# 92672                       0.814471   0.354807              1.012332
#
# [96 rows x 33 columns]

# %% [markdown]
# ### Clustering by Unsupervised Machine Learning

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Standardize features
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# Choose the number of clusters (n_clusters)
n_clusters = 8
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(scaled_data)

# Get cluster labels and centroids
cluster_labels = kmeans.labels_
centroids = kmeans.cluster_centers_
# Out:
# /Users/lizhihan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Assign label to each zipcode
original_df['label'] = cluster_labels

# %%
original_df[original_df['label'] == 0].mean()
# Out:
# Population                                      44953.750000
# Land Area (Sq. Miles)                              21.086667
# Population Density (People per Square Mile)      4525.615417
# Median Age                                         34.850000
# Population By Age % (Under 18 Years)               23.892083
# Population By Age % (18 to 34)                     26.272500
# Population By Age % (35 to 64)                     37.304167
# Population By Age % (65 and Over)                  66.073333
# Male %                                             50.314167
# White %                                            38.187500
# Black %                                             7.202917
# Asian %                                            10.644167
# Hispanic %                                         38.505417
# Other %                                             5.460000
# Less Than High School %                            13.718333
# High School Grad or Higher %                       86.281667
# Bachelor's Degree or Higher %                      28.870417
# Media Household Income $                        77567.625000
# Gini Index                                          0.424583
# Unemployed %                                        6.865833
# Poverty %                                          13.966667
# Average Commute to Work (min)                      28.916667
# Drove Alone %                                      74.770833
# Carpooled %                                         9.162500
# Public Transit %                                    2.663333
# Motorcycle %                                        0.537917
# Bicycle %                                           0.207500
# Walked %                                            1.750833
# Other %.1                                           1.200833
# Worked at Home %                                    9.707083
# Health Insurance Coverage %                        91.310833
# Married %                                          47.736250
# Median House Value $                           526495.833333
# label                                               0.000000
# dtype: float64

# %%
original_df[original_df['label'] == 1].mean()
# Out:
# Population                                       20655.400
# Land Area (Sq. Miles)                               34.202
# Population Density (People per Square Mile)       2596.776
# Median Age                                          44.690
# Population By Age % (Under 18 Years)                20.578
# Population By Age % (18 to 34)                      17.199
# Population By Age % (35 to 64)                      40.461
# Population By Age % (65 and Over)                   21.762
# Male %                                              49.594
# White %                                             71.134
# Black %                                              1.045
# Asian %                                              6.688
# Hispanic %                                          15.232
# Other %                                              5.901
# Less Than High School %                              3.905
# High School Grad or Higher %                        96.095
# Bachelor's Degree or Higher %                       65.696
# Media Household Income $                        132372.000
# Gini Index                                           0.499
# Unemployed %                                         3.775
# Poverty %                                            7.875
# Average Commute to Work (min)                       24.200
# Drove Alone %                                       63.904
# Carpooled %                                          5.274
# Public Transit %                                     1.065
# Motorcycle %                                         1.156
# Bicycle %                                            1.186
# Walked %                                             3.840
# Other %.1                                            1.375
# Worked at Home %                                    22.201
# Health Insurance Coverage %                         95.038
# Married %                                           57.644
# Median House Value $                           1308980.100
# label                                                1.000
# dtype: float64

# %%
original_df[original_df['label'] == 2].mean()
# Out:
# Population                                      40472.842105
# Land Area (Sq. Miles)                              16.573158
# Population Density (People per Square Mile)      3647.235263
# Median Age                                         39.273684
# Population By Age % (Under 18 Years)               24.120000
# Population By Age % (18 to 34)                     20.485263
# Population By Age % (35 to 64)                     40.290000
# Population By Age % (65 and Over)                  15.103158
# Male %                                             49.704737
# White %                                            50.474737
# Black %                                             3.132105
# Asian %                                            19.297895
# Hispanic %                                         20.754737
# Other %                                             6.340526
# Less Than High School %                             5.381053
# High School Grad or Higher %                       94.618947
# Bachelor's Degree or Higher %                      55.148947
# Media Household Income $                       123848.789474
# Gini Index                                          0.401579
# Unemployed %                                        6.061053
# Poverty %                                           5.833158
# Average Commute to Work (min)                      25.947368
# Drove Alone %                                      72.980000
# Carpooled %                                         6.840000
# Public Transit %                                    1.083158
# Motorcycle %                                        0.356316
# Bicycle %                                           0.315263
# Walked %                                            1.361579
# Other %.1                                           0.841579
# Worked at Home %                                   16.221579
# Health Insurance Coverage %                        96.286316
# Married %                                          58.950000
# Median House Value $                           752594.736842
# label                                               2.000000
# dtype: float64

# %%
original_df[original_df['label'] == 3].mean()
# Out:
# Population                                      59222.200
# Land Area (Sq. Miles)                              12.943
# Population Density (People per Square Mile)      7524.322
# Median Age                                         34.460
# Population By Age % (Under 18 Years)               24.469
# Population By Age % (18 to 34)                     26.735
# Population By Age % (35 to 64)                     36.940
# Population By Age % (65 and Over)                  11.854
# Male %                                             49.752
# White %                                            16.354
# Black %                                             5.260
# Asian %                                             8.382
# Hispanic %                                         66.828
# Other %                                             3.176
# Less Than High School %                            26.724
# High School Grad or Higher %                       73.276
# Bachelor's Degree or Higher %                      18.980
# Media Household Income $                        62080.300
# Gini Index                                          0.444
# Unemployed %                                        8.834
# Poverty %                                          16.303
# Average Commute to Work (min)                      27.000
# Drove Alone %                                      72.678
# Carpooled %                                        11.811
# Public Transit %                                    5.442
# Motorcycle %                                        0.315
# Bicycle %                                           0.322
# Walked %                                            1.976
# Other %.1                                           1.026
# Worked at Home %                                    6.431
# Health Insurance Coverage %                        86.944
# Married %                                          45.772
# Median House Value $                           472080.000
# label                                               3.000
# dtype: float64

# %%
original_df[original_df['label'] == 4].mean()
# Out:
# Population                                      33150.000
# Land Area (Sq. Miles)                               5.410
# Population Density (People per Square Mile)      7456.766
# Median Age                                         34.790
# Population By Age % (Under 18 Years)               11.852
# Population By Age % (18 to 34)                     38.569
# Population By Age % (35 to 64)                     37.510
# Population By Age % (65 and Over)                  12.069
# Male %                                             52.430
# White %                                            59.499
# Black %                                             4.038
# Asian %                                            11.230
# Hispanic %                                         19.529
# Other %                                             5.704
# Less Than High School %                             3.952
# High School Grad or Higher %                       96.048
# Bachelor's Degree or Higher %                      61.137
# Media Household Income $                        89514.800
# Gini Index                                          0.449
# Unemployed %                                        5.355
# Poverty %                                          11.886
# Average Commute to Work (min)                      22.800
# Drove Alone %                                      66.816
# Carpooled %                                         5.458
# Public Transit %                                    3.587
# Motorcycle %                                        0.477
# Bicycle %                                           1.600
# Walked %                                            4.061
# Other %.1                                           1.273
# Worked at Home %                                   16.728
# Health Insurance Coverage %                        94.120
# Married %                                          37.712
# Median House Value $                           753450.000
# label                                               4.000
# dtype: float64

# %%
original_df[original_df['label'] == 5].mean()
# Out:
# Population                                       2779.00
# Land Area (Sq. Miles)                             914.88
# Population Density (People per Square Mile)         3.04
# Median Age                                         62.80
# Population By Age % (Under 18 Years)               10.69
# Population By Age % (18 to 34)                      9.86
# Population By Age % (35 to 64)                     32.82
# Population By Age % (65 and Over)                  46.64
# Male %                                             42.75
# White %                                            64.66
# Black %                                             0.04
# Asian %                                             0.04
# Hispanic %                                         35.26
# Other %                                             0.00
# Less Than High School %                             8.56
# High School Grad or Higher %                       91.44
# Bachelor's Degree or Higher %                      28.53
# Media Household Income $                        83676.00
# Gini Index                                          0.37
# Unemployed %                                       10.06
# Poverty %                                           2.91
# Average Commute to Work (min)                      22.00
# Drove Alone %                                      63.72
# Carpooled %                                         0.10
# Public Transit %                                    0.00
# Motorcycle %                                        0.00
# Bicycle %                                           0.00
# Walked %                                            0.20
# Other %.1                                           0.00
# Worked at Home %                                   35.98
# Health Insurance Coverage %                        94.60
# Married %                                          69.04
# Median House Value $                           320600.00
# label                                               5.00
# dtype: float64

# %%
original_df[original_df['label'] == 6].mean()
# Out:
# Population                                      22821.105263
# Land Area (Sq. Miles)                              91.246316
# Population Density (People per Square Mile)       860.720000
# Median Age                                         45.273684
# Population By Age % (Under 18 Years)               19.425789
# Population By Age % (18 to 34)                     19.432105
# Population By Age % (35 to 64)                     40.251053
# Population By Age % (65 and Over)                  20.894211
# Male %                                             50.462632
# White %                                            65.915789
# Black %                                             1.607895
# Asian %                                             3.702632
# Hispanic %                                         23.519474
# Other %                                             5.254211
# Less Than High School %                             8.573684
# High School Grad or Higher %                       91.426316
# Bachelor's Degree or Higher %                      33.244211
# Media Household Income $                        89884.526316
# Gini Index                                          0.443158
# Unemployed %                                        6.197895
# Poverty %                                           9.692632
# Average Commute to Work (min)                      33.210526
# Drove Alone %                                      77.458947
# Carpooled %                                         6.674737
# Public Transit %                                    0.628421
# Motorcycle %                                        0.249474
# Bicycle %                                           0.155263
# Walked %                                            2.068947
# Other %.1                                           1.014211
# Worked at Home %                                   11.749474
# Health Insurance Coverage %                        94.195789
# Married %                                          55.256316
# Median House Value $                           595926.315789
# label                                               6.000000
# dtype: float64

# %%
original_df[original_df['label'] == 7].mean()
# Out:
# Population                                       1336.000000
# Land Area (Sq. Miles)                              63.953333
# Population Density (People per Square Mile)        35.893333
# Median Age                                         45.666667
# Population By Age % (Under 18 Years)               21.556667
# Population By Age % (18 to 34)                     17.010000
# Population By Age % (35 to 64)                     38.213333
# Population By Age % (65 and Over)                  23.220000
# Male %                                             52.573333
# White %                                            39.370000
# Black %                                             0.653333
# Asian %                                             2.180000
# Hispanic %                                         29.063333
# Other %                                            28.733333
# Less Than High School %                            18.100000
# High School Grad or Higher %                       81.900000
# Bachelor's Degree or Higher %                      25.403333
# Media Household Income $                        80355.000000
# Gini Index                                          0.403333
# Unemployed %                                        3.950000
# Poverty %                                          11.816667
# Average Commute to Work (min)                      28.666667
# Drove Alone %                                      81.153333
# Carpooled %                                         1.513333
# Public Transit %                                    0.133333
# Motorcycle %                                        0.000000
# Bicycle %                                           0.200000
# Walked %                                            1.060000
# Other %.1                                           0.000000
# Worked at Home %                                   15.940000
# Health Insurance Coverage %                        78.520000
# Married %                                          53.383333
# Median House Value $                           393800.000000
# label                                               7.000000
# dtype: float64

# %%
# Assuming 'data' is your preprocessed and scaled data, and 'cluster_labels' are the cluster assignments
variances = np.var(df, axis=0)
feature_ranking = np.argsort(variances)[::-1]  # Features with highest variance first

print("Ranking of features by variance:")
for idx in feature_ranking:
    print(f"{df.columns[idx]}, Variance = {variances[idx]}")
# Out:
# Ranking of features by variance:
# Gini Index, Variance = 1.0000000000000007
# Population By Age % (18 to 34), Variance = 1.0000000000000007
# Motorcycle %, Variance = 1.0000000000000004
# Married %, Variance = 1.0000000000000004
# Average Commute to Work (min), Variance = 1.0000000000000004
# Media Household Income $, Variance = 1.0000000000000004
# Bachelor's Degree or Higher %, Variance = 1.0000000000000002
# Land Area (Sq. Miles), Variance = 1.0000000000000002
# Median Age, Variance = 1.0000000000000002
# Population By Age % (35 to 64), Variance = 1.0000000000000002
# Asian %, Variance = 1.0000000000000002
# Other %, Variance = 1.0000000000000002
# High School Grad or Higher %, Variance = 1.0000000000000002
# Population, Variance = 1.0000000000000002
# Unemployed % , Variance = 1.0000000000000002
# Worked at Home %, Variance = 1.0000000000000002
# Walked %, Variance = 1.0000000000000002
# Public Transit %, Variance = 1.0000000000000002
# Black %, Variance = 1.0
# Population By Age % (Under 18 Years), Variance = 1.0
# Population By Age % (65 and Over), Variance = 1.0
# Median House Value $, Variance = 1.0
# Less Than High School %, Variance = 1.0
# Poverty %, Variance = 0.9999999999999997
# Hispanic %, Variance = 0.9999999999999997
# Drove Alone %, Variance = 0.9999999999999997
# Health Insurance Coverage %, Variance = 0.9999999999999997
# Bicycle %, Variance = 0.9999999999999996
# Male %, Variance = 0.9999999999999996
# Carpooled %, Variance = 0.9999999999999996
# Population Density (People per Square Mile), Variance = 0.9999999999999996
# White %, Variance = 0.9999999999999996
# Other %.1, Variance = 0.9999999999999994

# %%
excel_filename = 'labeled SD zipcode.csv' 
original_df.to_csv(excel_filename, index=True)
